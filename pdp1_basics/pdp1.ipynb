# %%
## Foundations - Variables, Input, Conditions and Loops

# %%
print("Hello, python1")

age = 36
height = 5.5
name = "Sid"
is_student = True



print(age)
print(height)
print(name)
print(is_student)
# Out:
# Hello, python1
# 36
# 5.5
# Sid
# True

# %%
print(type(age))
print(type(height))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x = 10
y = 3

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x // y)
print(x % y)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1

# %%
first_name = "Sudipto"
last_name = "Bhadra"

full_name = first_name+" "+last_name
print(full_name)


print(full_name.upper())
print(full_name.lower())
print(len(full_name))
# Out:
# Sudipto Bhadra
# SUDIPTO BHADRA
# sudipto bhadra
# 14

# %%
city = "SilverSpring"
profession = "IT"
yoe = 10

print("My name is Sid. "+ " I live in " +city+ "." + " I work as " + profession+"."+" I have {} years of experience".format(yoe))
# Out:
# My name is Sid.  I live in SilverSpring. I work as IT. I have 10 years of experience

# %%
## BEST WAY TO PRINT
## REAL PYTHON DEVELOPERS WRITE LIKE THIS


print(
    f"My name is Sid. I live in {city}."
    f"I work as {profession}. "
    f"I have {yoe} years of experience"

    
)
# Out:
# My name is Sid. I live in SilverSpring.I work as IT. I have 10 years of experience

# %%
year = 2025


print(
    f"My name is Sid. I live in {city}. "
    f"I work as {profession}."
    f"I have {yoe} years of experience"
    f" as of {year}"


    
)
# Out:
# My name is Sid. I live in SilverSpring. I work as IT.I have 10 years of experience as of 2025

# %%
name = input('Enter your name')
print(f"Hello {name}")
# Out:
# Enter your name sid
# Hello sid

# %%
agee = int(input('Enter the age: '))
print(agee+5)
# Out:
# Enter the age:  67
# 72

# %%
mage = int(input('Enter your age: '))

if mage>18:
    print('You can vote! ')
else:
    print('Become 18 y first')
# Out:
# Enter your age:  6
# Become 18 y first

# %%
score = int(input("Enter your score: "))


if score>=90:
    print("Grade A")
elif score >=75:
    print("G B")
elif score >=60:
    print("G C")
else:
    print("Too Bad")
# Out:
# Enter your score:  67
# G C

# %%
yoex = int(input("Enter your years of experience: "))


if yoex < 3:
    print('Entry level: ')
elif 3<yoex<7:
    print("Mid Level")
else:
    print("Senior Level")
# Out:
# Enter your years of experience:  6
# Mid Level

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,6):
    print(f"count: {i}")
# Out:
# count: 1
# count: 2
# count: 3
# count: 4
# count: 5

# %%
languages = ["Python"," R","SQL","JS"]

for lang in languages:
    print(lang)
# Out:
# Python
#  R
# SQL
# JS

# %%
count = 1

while count <=5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n = int(input('enter a number to print from 1: '))

for i in range(1,n+1):
    if i ==3:
        continue
    print(i)
    i = i+1
# Out:
# enter a number to print from 1:  7
# 1
# 2
# 4
# 5
# 6
# 7

# %%
a = int(input('Enter a number: '))

numbers = [i for i in range(1,n+1) if i!=3]
print(numbers)
# Out:
# Enter a number:  5
# [1, 2, 4, 5, 6, 7]

# %%
'''DAY-1 COMPLETE CHECKLIST

✔️ Variables
✔️ Printing
✔️ Input
✔️ Conditions
✔️ Loops
✔️ Debugging

'''
# Out:
# 'DAY-1 COMPLETE CHECKLIST\n\n✔️ Variables\n✔️ Printing\n✔️ Input\n✔️ Conditions\n✔️ Loops\n✔️ Debugging\n\n'
